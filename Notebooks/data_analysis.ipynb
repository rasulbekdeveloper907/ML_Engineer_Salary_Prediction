# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\Rasulbek_Ruzmetov\Desktop\SML_R_Project\Data\Raw_Data\global_ai_ml_data_salaries.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2024               SE              FT   Data Architect  170955
# 1       2024               SE              FT   Data Architect  130270
# 2       2024               MI              FT  Insight Analyst   92144
# 3       2024               MI              FT  Insight Analyst   57616
# 4       2024               SE              FT    Lead Engineer  201600
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         170955                 US             0
# 1             USD         130270                 US             0
# 2             USD          92144                 US           100
# 3             USD          57616                 US           100
# 4             USD         201600                 US           100
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# ...

# %% [markdown]
# # Job titles

# %%
from tabulate import tabulate

job_titles = df["job_title"].unique()
job_titles_df = pd.DataFrame(job_titles, columns=["Job Title"])

print(tabulate(job_titles_df, headers="keys", tablefmt="pretty"))
# Out:
# +-----+------------------------------------------+
# |     |                Job Title                 |
# +-----+------------------------------------------+
# |  0  |              Data Architect              |
# |  1  |             Insight Analyst              |
# |  2  |              Lead Engineer               |
# |  3  |        Machine Learning Engineer         |
# |  4  |              Data Scientist              |
# |  5  |                 Manager                  |
# |  6  |                Associate                 |
# |  7  |              Data Engineer               |
# |  8  |     Business Intelligence Developer      |
# |  9  |             Product Manager              |
# | 10  |               BI Developer               |
# | 11  |               Data Analyst               |
# | 12  |           Engineering Manager            |
# | 13  |            Research Scientist            |
# | 14  |            Software Engineer             |
# ...

# %% [markdown]
# # Har bitta kasbdan nechta malumot borligi

# %%
from tabulate import tabulate

job_counts = df["job_title"].value_counts().reset_index()
job_counts.columns = ["Job Title", "Count"]

print(tabulate(job_counts, headers="keys", tablefmt="pretty"))
# Out:
# +-----+------------------------------------------+-------+
# |     |                Job Title                 | Count |
# +-----+------------------------------------------+-------+
# |  0  |              Data Scientist              | 7776  |
# |  1  |              Data Engineer               | 6415  |
# |  2  |               Data Analyst               | 4607  |
# |  3  |        Machine Learning Engineer         | 4144  |
# |  4  |            Software Engineer             | 3436  |
# |  5  |            Research Scientist            | 1643  |
# |  6  |            Applied Scientist             |  927  |
# |  7  |                 Engineer                 |  886  |
# |  8  |              Data Architect              |  867  |
# |  9  |            Analytics Engineer            |  790  |
# | 10  |            Research Engineer             |  728  |
# | 11  |                 Manager                  |  568  |
# | 12  |      Business Intelligence Engineer      |  446  |
# ...

# %%
# Machine Learning Engineer larni ajratib olib df ga yozish
df = df[df["job_title"] == "Machine Learning Engineer"]

# %%
df.head()
# Out:
#      work_year experience_level employment_type                  job_title  \
# 6         2024               SE              FT  Machine Learning Engineer
# 7         2024               SE              FT  Machine Learning Engineer
# 8         2024               SE              FT  Machine Learning Engineer
# 9         2024               SE              FT  Machine Learning Engineer
# 148       2024               SE              FT  Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 6    296300             USD         296300                 US             0
# 7    166600             USD         166600                 US             0
# 8    264200             USD         264200                 US             0
# 9    143100             USD         143100                 US             0
# 148   50000             EUR          55555                 LT             0
#
#     company_location company_size
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4144 entries, 6 to 40321
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           4144 non-null   int64
#  1   experience_level    4144 non-null   object
#  2   employment_type     4144 non-null   object
#  3   job_title           4144 non-null   object
#  4   salary              4144 non-null   int64
#  5   salary_currency     4144 non-null   object
#  6   salary_in_usd       4144 non-null   int64
#  7   employee_residence  4144 non-null   object
#  8   remote_ratio        4144 non-null   int64
#  9   company_location    4144 non-null   object
#  10  company_size        4144 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 388.5+ KB

# %% [markdown]
# # Maoshlar haqida taqsimot jadvali

# %%
import matplotlib.pyplot as plt

# Ma'lumotlar
labels = ["Eng past maosh", "Eng yuqori maosh", "O‘rtacha maosh", "Median maosh"]
values = [min_salary, max_salary, mean_salary, median_salary]

# Grafik chizish
plt.figure(figsize=(8,5))
plt.bar(labels, values, color=["blue", "red", "green", "orange"])
plt.title("📊 Machine Learning Engineer Maosh Statistikasi")
plt.ylabel("USD ($)")
plt.xticks(rotation=15)

# Qiymatlarni ustiga yozib qo‘yish
for i, v in enumerate(values):
    plt.text(i, v + (v*0.02), f"{v:,.0f}", ha="center", fontsize=10)

plt.show()
# Out:
# c:\Users\Rasulbek_Ruzmetov\Desktop\SML_R_Project\myvenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Mamlakatlar bo`yicha taqsimot

# %%
import matplotlib.pyplot as plt

# Mamlakatlar va soni
countries = ["US", "CA", "GB", "DE", "AU", "LT", "IN", "ES", "NL", "FR"]
counts = [3808, 152, 68, 21, 15, 6, 6, 6, 5, 5]

# Grafik (bar chart)
plt.figure(figsize=(10,6))
plt.bar(countries, counts, color="blue", edgecolor="black")

plt.title("🌍 Machine Learning Engineer lar mamlakatlar bo‘yicha taqsimoti (Top 10)")
plt.xlabel("Mamlakat")
plt.ylabel("Soni")
plt.xticks(rotation=0)

# Qiymatlarni ustiga yozib qo‘yish
for i, v in enumerate(counts):
    plt.text(i, v + (v*0.02), str(v), ha="center", fontsize=10)

plt.show()

# %% [markdown]
# # Ish tajribasi bo`yicha taqsimot

# %%
import matplotlib.pyplot as plt

# Tajriba darajalari bo‘yicha soni
exp_counts = df["experience_level"].value_counts().reset_index()
exp_counts.columns = ["Experience Level", "Soni"]

print("📊 Tajriba darajasi bo‘yicha taqsimot:")
print(exp_counts)

# Grafik (bar chart)
plt.figure(figsize=(7,5))
plt.bar(exp_counts["Experience Level"], exp_counts["Soni"], color="lightgreen", edgecolor="black")

plt.title("Machine Learning Engineer tajriba darajalari bo‘yicha taqsimot")
plt.xlabel("Tajriba darajasi")
plt.ylabel("Soni")

# Qiymatlarni ustiga yozish
for i, v in enumerate(exp_counts["Soni"]):
    plt.text(i, v + (v*0.02), str(v), ha="center", fontsize=10)

plt.show()
# Out:
# 📊 Tajriba darajasi bo‘yicha taqsimot:
#   Experience Level  Soni
# 0               SE  3087
# 1               MI   800
# 2               EN   221
# 3               EX    36

# %% [markdown]
# # EN → Entry-level (yangi boshlovchi)
# # MI → Mid-level (o‘rta daraja)
# # SE → Senior-level (tajribali)
# # EX → Executive-level (rahbar / ekspert)

# %%
df.to_csv(r"C:\Users\Rasulbek_Ruzmetov\Desktop\SML_R_Project\Data\Raw_Data\ML_Engineeer.csv", index=False, encoding="utf-8")
